# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.misc import imread, imshow

# %%
dist1 = np.random.uniform(0,50, 1000000)

# %%
dist1[100:]
# Out:
# array([ 15.17101878,   5.6572414 ,  17.16440762, ...,  41.79933582,
#         47.41292038,  46.40533062])

# %%
max(dist1)
# Out:
# 49.999951776250825

# %%
min(dist1)
# Out:
# 1.1387427556464047e-06

# %%
dist1.mean()
# Out:
# 25.006911689906008

# %%
dist1.std()
# Out:
# 14.444364552296042

# %%
plt.hist(dist1)
plt.show()

# %%
dist2 = []
for i in range(10000):
    x = np.random.choice(dist1, 100)
    dist2.append(x.mean())

# %%
dist2 = np.array(dist2)

# %%
dist2.mean()
# Out:
# 25.006019052220719

# %%
dist2.std()
# Out:
# 1.4212871783704188

# %%
plt.hist(dist2, bins = 100)
plt.show()

# %%
np.array([10,20,30,40,50]).var()
# Out:
# 200.0

# %%
import xgboost as xgb
import numpy as np

# %%
dtrain = xgb.DMatrix("train.csv")

# %%
# %pylab inline
from pylab import *
import random as pyrandom
from scipy.spatial.distance import cdist
matplotlib.rc("image",cmap="gray")
from collections import Counter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = r_[10*randn(1000,2)+array([70,30]), 10*randn(1000,2)+array([10,10]), 10*randn(1000,2)+array([50,80])]

# %%
data.shape
# Out:
# (3000, 2)

# %%
data
# Out:
# array([[ 68.3282282 ,  15.62855293],
#        [ 67.05219799,  55.28418888],
#        [ 66.50908926,  21.83952049],
#        ...,
#        [ 50.21772028,  69.47005883],
#        [ 56.00104615,  78.14355071],
#        [ 66.81556811,  81.15257684]])

# %%
data = data[pyrandom.sample(range(len(data)),len(data))]

# %%
import scipy.misc

# %%
face = scipy.misc.face()

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.imshow(face)

# %%
f = scipy.misc.face(gray=True)

# %%
plt.figure(figsize = (16,9))
plt.imshow(f, cmap="gray")

# %%
f.shape
# Out:
# (768, 1024)

# %%
from scipy import signal

# %%
final_list = []
for i in range(0,f.shape[0],4):
    new_list = []
    for j in range(0, f.shape[1],4):
        new_list.append(f[i:i+4, j:j+4].mean())
    final_list.append(new_list)

# %%
len(final_list)
# Out:
# 192

# %%
import numpy as np

# %%
new_img = np.array(final_list)

# %%
new_img.shape
# Out:
# (192, 256)

# %%
plt.figure(figsize = (16,9))
plt.imshow(new_img, cmap="gray")
